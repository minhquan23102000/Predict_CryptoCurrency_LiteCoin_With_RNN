# %%
import os
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Bidirectional
from tensorflow.keras.metrics import MeanSquaredError
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

import matplotlib.pylab as pylab
params = {'legend.fontsize': 'large',
          'figure.titlesize': 'large',
          'figure.figsize': (11, 8),
         'axes.labelsize': 'large',
         'axes.titlesize':'large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'large'}
pylab.rcParams.update(params)

# %%
os.listdir('data')
# Out:
# ['coin_Aave.csv',
#  'coin_BinanceCoin.csv',
#  'coin_Bitcoin.csv',
#  'coin_Cardano.csv',
#  'coin_ChainLink.csv',
#  'coin_Cosmos.csv',
#  'coin_CryptocomCoin.csv',
#  'coin_Dogecoin.csv',
#  'coin_EOS.csv',
#  'coin_Ethereum.csv',
#  'coin_Iota.csv',
#  'coin_Litecoin.csv',
#  'coin_Monero.csv',
#  'coin_NEM.csv',
#  'coin_Polkadot.csv',
#  'coin_Solana.csv',
#  'coin_Stellar.csv',
#  'coin_Tether.csv',
#  'coin_Tron.csv',
#  'coin_Uniswap.csv',
#  'coin_USDCoin.csv',
#  'coin_WrappedBitcoin.csv',
#  'coin_XRP.csv']

# %%
ROOT_PATH = 'data'

# %% [markdown]
# # Step 1: Define Problem
# In this notebook we are going to build a RNN model for predicting crypto currency.
#
# My target is Litecoin Closing Price in the next day. I choose LiteCoin because it fit my pocket : )

# %% [markdown]
# # Step 2: Data Understanding
# The dataset we will use, was collected by Chennai, Tamil Nadu in Kaggle. You can get it from this link: https://www.kaggle.com/sudalairajkumar/cryptocurrencypricehistory
#
# ## **Data Content**
# The dataset has one csv file for each currency. Price history is available on a daily basis from April 28, 2013. This dataset has the historical price information of some of the top crypto currencies by market capitalization.
#
# - Date : date of observation
# - Open : Opening price on the given day
# - High : Highest price on the given day
# - Low : Lowest price on the given day
# - Close : Closing price on the given day
# - Volume : Volume of transactions on the given day
# - Market Cap : Market capitalization in USD

# %% [markdown]
# # Step 3: Preprocessing Data

# %%
coin_dataframes = dict()

def date_format(date_str):
    return pd.to_datetime(date_str)


for fn in os.listdir(ROOT_PATH):
    coin_name = fn.split("_")[1][:-4]
    df = pd.read_csv(os.path.join(ROOT_PATH, fn), parse_dates=['Date'], dayfirst=True)
    df['Date'] = df['Date'].dt.strftime('%Y-%m-%d')
    df = df.set_index('Date', drop=True)
    coin_dataframes[coin_name] = df.sort_values('Date')

# %%
coin_dataframes['Bitcoin'].tail()
# Out:
#              SNo     Name Symbol         High          Low         Open  \
# Date
# 2021-07-02  2987  Bitcoin    BTC  33939.58870  32770.68078  33549.60018
# 2021-07-03  2988  Bitcoin    BTC  34909.25990  33402.69654  33854.42136
# 2021-07-04  2989  Bitcoin    BTC  35937.56715  34396.47746  34665.56487
# 2021-07-05  2990  Bitcoin    BTC  35284.34443  33213.66103  35284.34443
# 2021-07-06  2991  Bitcoin    BTC  35038.53636  33599.91617  33723.50966
#
#                   Close        Volume     Marketcap
# Date
# 2021-07-02  33897.04859  3.872897e+10  6.350000e+11
# 2021-07-03  34668.54840  2.438396e+10  6.500000e+11
# 2021-07-04  35287.77977  2.492431e+10  6.620000e+11
# 2021-07-05  33746.00246  2.672155e+10  6.330000e+11
# 2021-07-06  34235.19345  2.650126e+10  6.420000e+11

# %%
for key, data in coin_dataframes.items():
    print(f"Coin {key} with data's length: {data.shape[0]}")
# Out:
# Coin Aave with data's length: 275
# Coin BinanceCoin with data's length: 1442
# Coin Bitcoin with data's length: 2991
# Coin Cardano with data's length: 1374
# Coin ChainLink with data's length: 1385
# Coin Cosmos with data's length: 845
# Coin CryptocomCoin with data's length: 935
# Coin Dogecoin with data's length: 2760
# Coin EOS with data's length: 1466
# Coin Ethereum with data's length: 2160
# Coin Iota with data's length: 1484
# Coin Litecoin with data's length: 2991
# Coin Monero with data's length: 2602
# Coin NEM with data's length: 2288
# Coin Polkadot with data's length: 320
# Coin Solana with data's length: 452
# Coin Stellar with data's length: 2527
# Coin Tether with data's length: 2318
# Coin Tron with data's length: 1392
# Coin Uniswap with data's length: 292
# Coin USDCoin with data's length: 1002
# Coin WrappedBitcoin with data's length: 888
# Coin XRP with data's length: 2893

# %%
#We will drop coin with size < 2000
keys = [k for k, v in coin_dataframes.items() if v.shape[0] < 2000]
for x in keys:
    del coin_dataframes[x]
    
for key, data in coin_dataframes.items():
    print(f"Coin {key} with data's length: {data.shape[0]}")
# Out:
# Coin Bitcoin with data's length: 2991
# Coin Dogecoin with data's length: 2760
# Coin Ethereum with data's length: 2160
# Coin Litecoin with data's length: 2991
# Coin Monero with data's length: 2602
# Coin NEM with data's length: 2288
# Coin Stellar with data's length: 2527
# Coin Tether with data's length: 2318
# Coin XRP with data's length: 2893

# %%
#Get 2160 most recent records for each coin. For synchronizing training_set

for key, data in coin_dataframes.items():
    coin_dataframes[key] = coin_dataframes[key][-2160:]
    
for key, data in coin_dataframes.items():
    print(f"Coin {key} with data's length: {data.shape[0]}")
# Out:
# Coin Bitcoin with data's length: 2160
# Coin Dogecoin with data's length: 2160
# Coin Ethereum with data's length: 2160
# Coin Litecoin with data's length: 2160
# Coin Monero with data's length: 2160
# Coin NEM with data's length: 2160
# Coin Stellar with data's length: 2160
# Coin Tether with data's length: 2160
# Coin XRP with data's length: 2160

# %%
#Detect missing value

for key in coin_dataframes.keys():
    print(f"Coin {key} with total nan values:\n{coin_dataframes[key].isna().sum()} ")
# Out:
# Coin Bitcoin with total nan values:
# SNo          0
# Name         0
# Symbol       0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64
# Coin Dogecoin with total nan values:
# SNo          0
# Name         0
# Symbol       0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64
# Coin Ethereum with total nan values:
# SNo          0
# Name         0
# Symbol       0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64
# Coin Litecoin with total nan values:
# SNo          0
# Name         0
# Symbol       0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64
# Coin Monero with total nan values:
# SNo          0
# Name         0
# Symbol       0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64
# Coin NEM with total nan values:
# SNo          0
# Name         0
# Symbol       0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64
# Coin Stellar with total nan values:
# SNo          0
# Name         0
# Symbol       0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64
# Coin Tether with total nan values:
# SNo          0
# Name         0
# Symbol       0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64
# Coin XRP with total nan values:
# SNo          0
# Name         0
# Symbol       0
# High         0
# Low          0
# Open         0
# Close        0
# Volume       0
# Marketcap    0
# dtype: int64

# %%
# Percent Change Closing Price Per Day for each Coin
for coin in coin_dataframes.keys():
    coin_dataframes[coin]['ClosePctChg'] = coin_dataframes[coin]['Close'].pct_change().fillna(0)
    
for coin in coin_dataframes.keys():
    plt.plot(coin_dataframes[coin]['ClosePctChg'], label=coin)
plt.legend(loc=2)
plt.title('Daily Percent Change of Closing Price')
plt.show()

# %%
# See their correlation
data = pd.DataFrame()

for k, v in coin_dataframes.items():
    data[k] = v['ClosePctChg']

corrmat = data.corr()

corrmat
# Out:
#            Bitcoin  Dogecoin  Ethereum  Litecoin    Monero       NEM  \
# Bitcoin   1.000000  0.335172  0.515587  0.649799  0.535185  0.381678
# Dogecoin  0.335172  1.000000  0.241976  0.328242  0.241430  0.205893
# Ethereum  0.515587  0.241976  1.000000  0.502817  0.441758  0.325970
# Litecoin  0.649799  0.328242  0.502817  1.000000  0.482823  0.400920
# Monero    0.535185  0.241430  0.441758  0.482823  1.000000  0.311696
# NEM       0.381678  0.205893  0.325970  0.400920  0.311696  1.000000
# Stellar   0.396056  0.309309  0.339368  0.417873  0.382610  0.390143
# Tether   -0.008574 -0.017885 -0.007316 -0.025426 -0.021276 -0.045381
# XRP       0.344906  0.250149  0.309339  0.409793  0.301566  0.297554
#
#            Stellar    Tether       XRP
# Bitcoin   0.396056 -0.008574  0.344906
# Dogecoin  0.309309 -0.017885  0.250149
# Ethereum  0.339368 -0.007316  0.309339
# Litecoin  0.417873 -0.025426  0.409793
# Monero    0.382610 -0.021276  0.301566
# NEM       0.390143 -0.045381  0.297554
# Stellar   1.000000  0.002146  0.544366
# Tether    0.002146  1.000000 -0.021132
# XRP       0.544366 -0.021132  1.000000

# %%
#Plot the corrmat
sns.heatmap(corrmat, annot=True);

# %%
coin_dataframes['Litecoin'].describe()
# Out:
#                SNo         High          Low         Open        Close  \
# count  2160.000000  2160.000000  2160.000000  2160.000000  2160.000000
# mean   1911.500000    68.301917    62.475240    65.535192    65.578829
# std     623.682612    71.261533    63.337469    67.569113    67.538078
# min     832.000000     2.724670     2.543790     2.638140     2.633140
# 25%    1371.750000     4.241605     4.073073     4.160737     4.162520
# 50%    1911.500000    50.926489    47.456308    49.009223    49.080577
# 75%    2451.250000    86.438524    80.475550    83.439597    83.572502
# max    2991.000000   412.960141   345.298839   387.869178   386.450779
#
#              Volume     Marketcap  ClosePctChg
# count  2.160000e+03  2.160000e+03  2160.000000
# mean   1.777760e+09  3.990192e+09     0.003285
# std    2.474449e+09  4.211432e+09     0.058109
# min    5.074800e+05  1.109224e+08    -0.361773
# 25%    7.898028e+06  2.025372e+08    -0.019902
# 50%    4.702091e+08  3.022224e+09    -0.000326
# 75%    2.851648e+09  5.015291e+09     0.022788
# max    1.799426e+10  2.579652e+10     0.667653

# %%
#Which features has most correlation with Ethereum Close Price
corrmat = coin_dataframes['Litecoin'].corr()
sns.heatmap(corrmat, annot=True);

# %%
#Select best coins have most correlation with Ethereum Closing Price
dataset = pd.DataFrame()
for k in coin_dataframes.keys():
    if k in ['Litecoin', 'Bitcoin']:
        for col in coin_dataframes[k].columns:
            if col in ['Open', 'Close', 'High', 'Low']: 
                dataset[k+'_'+col] = coin_dataframes[k][col]
        
dataset.tail()
# Out:
#             Bitcoin_High  Bitcoin_Low  Bitcoin_Open  Bitcoin_Close  \
# Date
# 2021-07-02   33939.58870  32770.68078   33549.60018    33897.04859
# 2021-07-03   34909.25990  33402.69654   33854.42136    34668.54840
# 2021-07-04   35937.56715  34396.47746   34665.56487    35287.77977
# 2021-07-05   35284.34443  33213.66103   35284.34443    33746.00246
# 2021-07-06   35038.53636  33599.91617   33723.50966    34235.19345
#
#             Litecoin_High  Litecoin_Low  Litecoin_Open  Litecoin_Close
# Date
# 2021-07-02     138.787700    130.935471     137.299274      136.943696
# 2021-07-03     141.356011    134.945288     136.930584      140.279688
# 2021-07-04     147.836059    137.096427     140.317998      144.905849
# 2021-07-05     144.849333    134.960263     144.849333      138.073246
# 2021-07-06     142.703568    135.924837     137.951668      138.985636

# %%
#Split train test
training_set = dataset[:2000].copy()
test_set = dataset[2000:].copy()

training_set.shape, test_set.shape
# Out:
# ((2000, 8), (160, 8))

# %%
#Log transform data
for col in training_set.columns:
    training_set.loc[:,col] = np.log1p(training_set[col])
    test_set.loc[:, col] = np.log1p(test_set[col])

#Scaling data
scaler= MinMaxScaler(feature_range=(0,1))
training_set = scaler.fit_transform(training_set)
test_set = scaler.transform(test_set)

# %%
target = 'Litecoin_Close'
target_index = list(dataset.columns).index(target)
target_index
# Out:
# 7

# %%
# Create sequences input data
X_train = []
y_train = []
window_size = 14
time_step_future = 7

for i in range(window_size, len(training_set)- time_step_future):
    
    #Make output data. There are three output, one is the yester day price, two is current_day price and three is closing price of time_step_future days later
    #RNN is a bit slowly react to the trend of coin. So i let it looks up far more into future, for well adapted model.
    t = []
    t.append(training_set[i-1, target_index])
    t.append(training_set[i, target_index])
    t.append(training_set[i+time_step_future, target_index])
    y_train.append(t)
    
    
    #Create X train data
    X_train.append(training_set[i-window_size:i, :])



X_train, y_train = np.array(X_train), np.array(y_train)
X_train.shape, y_train.shape
# Out:
# ((1979, 14, 8), (1979, 3))

# %% [markdown]
# # Step 4: Building model

# %%
#Init rnn
regressor = Sequential()

#Adding first layer LSTM
regressor.add(Bidirectional( LSTM(units=50, return_sequences=True, input_shape=(window_size,X_train.shape[2])) ) )
regressor.add(Dropout(0.3))

#Adding second layer LSTM
regressor.add(LSTM(units=50, return_sequences=True)) 
regressor.add(Dropout(0.3))

#Adding third layer LSTM
regressor.add( LSTM(units=50) )
regressor.add(Dropout(0.3))

#Adding fourth layer LSTM
#regressor.add(LSTM(units=86))
#regressor.add(Dropout(0.2))

#Adding fifth layers LSTM
#regressor.add(LSTM(units = 64))
#regressor.add(Dropout(0.2))

#Adding output layers
regressor.add(Dense(units=3, activation = 'relu'))

#regressor.summary()

# %%
#Complie RNN
regressor.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# ### Fitting to training_set

# %%
regressor.fit(x = X_train, y = y_train, epochs=120, batch_size=32)
# Out:
# Epoch 1/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0936
# Epoch 2/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0107
# Epoch 3/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0086
# Epoch 4/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0080
# Epoch 5/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0069
# Epoch 6/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0062
# Epoch 7/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0056
# Epoch 8/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0051
# Epoch 9/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0045: 0s - lo
# Epoch 10/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0043
# Epoch 11/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0044
# Epoch 12/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0038
# Epoch 13/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0045
# Epoch 14/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0036
# Epoch 15/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0038
# Epoch 16/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0034
# Epoch 17/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0032
# Epoch 18/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0030
# Epoch 19/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0030
# Epoch 20/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0030
# Epoch 21/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0028
# Epoch 22/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0028
# Epoch 23/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0029
# Epoch 24/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0027
# Epoch 25/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0026
# Epoch 26/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0025
# Epoch 27/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0023
# Epoch 28/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0023
# Epoch 29/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 30/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0022
# Epoch 31/120
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0023
# Epoch 32/120
# 62/62 [==============================] - ETA: 0s - loss: 0.002 - 1s 11ms/step - loss: 0.0024
# Epoch 33/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0022
# Epoch 34/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0021
# Epoch 35/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0022
# Epoch 36/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0020
# Epoch 37/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0019
# Epoch 38/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0019
# Epoch 39/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0019
# Epoch 40/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0020
# Epoch 41/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0017
# Epoch 42/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0020
# Epoch 43/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0019
# Epoch 44/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0018
# Epoch 45/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0018
# Epoch 46/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0020
# Epoch 47/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0016
# Epoch 48/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0017
# Epoch 49/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 50/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0017
# Epoch 51/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 52/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0018
# Epoch 53/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 54/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0017
# Epoch 55/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0016
# Epoch 56/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 57/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 58/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 59/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 60/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0016
# Epoch 61/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0016
# Epoch 62/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0017
# Epoch 63/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 64/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 65/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 66/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 67/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 68/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0016
# Epoch 69/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 70/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 71/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 72/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 73/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 74/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 75/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 76/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0014
# Epoch 77/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 78/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 79/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 80/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 81/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0015
# Epoch 82/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 83/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0015
# Epoch 84/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0014
# Epoch 85/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 86/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 87/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0015
# Epoch 88/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 89/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 90/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 91/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0015
# Epoch 92/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 93/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 94/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0014
# Epoch 95/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 96/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 97/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 98/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0013
# Epoch 99/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0014
# Epoch 100/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0014
# Epoch 101/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 102/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 103/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 104/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0013
# Epoch 105/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 106/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 107/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 108/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 109/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 110/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 111/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0012
# Epoch 112/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 113/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0013
# Epoch 114/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 115/120
# 62/62 [==============================] - 1s 13ms/step - loss: 0.0013
# Epoch 116/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0014
# Epoch 117/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 118/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0012
# Epoch 119/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0013
# Epoch 120/120
# 62/62 [==============================] - 1s 12ms/step - loss: 0.0013

# %% [markdown]
# # Step 5: Evaluation model

# %%
X_train.shape
# Out:
# (1979, 14, 8)

# %%
def unscale_y(y_pred):
    t = np.zeros(shape=(len(y_pred), X_train.shape[2]))
    t[:, target_index] = y_pred
    t = scaler.inverse_transform(t)[:, target_index]
    t = np.expm1(t)
    return t

# %%
#Get predicted closing price on training set for three output, and unscale them
y_pred = regressor.predict(X_train)
y_pred_yesterday = unscale_y(y_pred[:,0])
y_pred_current_day = unscale_y(y_pred[:,1])
y_pred_next_week = unscale_y(y_pred[:,2])

y_pred_next_week.shape, y_pred_yesterday.shape, y_pred_current_day.shape
# Out:
# ((1979,), (1979,), (1979,))

# %%
#Get real closing price on training set
y_real_yesterday = dataset[window_size-1:2000-time_step_future-1][target].values
y_real_current_day = dataset[window_size:2000-time_step_future][target].values
y_real_next_week = dataset[window_size+time_step_future:2000][target].values

y_real_next_week.shape, y_real_yesterday.shape, y_real_current_day.shape
# Out:
# ((1979,), (1979,), (1979,))

# %%
def make_plot_evaluation(y_real, y_pred, title):
    # Visualising the results
    plt.plot(y_real, color = 'red', label = 'Real  Closing Price')

    plt.plot(y_pred, color = 'blue', label = 'Predict  Closing Price')

    plt.title(title)
    plt.xlabel('Time')
    plt.ylabel('Closing Price')
    plt.legend()
    plt.show()

# %%
make_plot_evaluation(y_real_yesterday, y_pred_yesterday, 'Litecoin Yesterday Closing Price Evaluation')
make_plot_evaluation(y_real_current_day, y_pred_current_day, 'Litecoin Today Closing Price Evaluation')
make_plot_evaluation(y_real_next_week, y_pred_next_week, 'Litecoin Next Week Closing Price Evaluation')

# %% [markdown]
# ## Evalution on test_set

# %%
test_set.shape
# Out:
# (160, 8)

# %%
#Generate test set
inputs = dataset[dataset.shape[0] - test_set.shape[0] - window_size: ].values
inputs = np.log1p(inputs)
inputs = scaler.transform(inputs)

# %%
# Create sequences input data
X_test = []

for i in range(window_size, len(inputs)-time_step_future):
    X_test.append(inputs[i-window_size:i, :])



X_test = np.array(X_test)
X_test.shape
# Out:
# (153, 14, 8)

# %%
#Get predicted values
y_pred = regressor.predict(X_test)
y_pred_yesterday = unscale_y(y_pred[:,0])
y_pred_current_day = unscale_y(y_pred[:,1])
y_pred_next_week = unscale_y(y_pred[:,2])
#Get real values
y_real_yesterday = dataset[2000-1:-time_step_future-1][target].values
y_real_current_day = dataset[2000:-time_step_future][target].values
y_real_next_week = dataset[time_step_future+2000: ][target].values

# Visualising the results
plt.plot(y_pred_current_day, color = 'green', label='Today pred closing price')
plt.plot(y_pred_yesterday, color = 'yellow', label = 'Yesterday')
plt.plot(y_pred_next_week, color = 'red', label = 'Next week')
plt.plot(y_real_current_day, color = 'black', label ='Real today')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

print(f"Mean square error on test: {mean_squared_error(y_pred=y_pred_current_day, y_true=y_real_current_day)}")
print(f"Mean absolute error on test: {mean_absolute_error(y_pred=y_pred_current_day, y_true=y_real_current_day)}")
print(f"R2 score on test: {r2_score(y_pred=y_pred_current_day, y_true=y_real_current_day)}")
# Out:
# Mean square error on test: 372.5251636978518
# Mean absolute error on test: 13.96947269439031
# R2 score on test: 0.8854942982614012

# %% [markdown]
# # Let run simulation of selling and buying coin with this model.
#
# Let say I invest 2000$ for this time. And after 160 days, how much money i will get, or i lose them all?

# %%
X_train.shape
# Out:
# (1979, 14, 8)

# %%
import math
#Create a predict function
def predict_closing_price(model, X):
    X = np.reshape(X, (1, window_size, X_train.shape[2]))
    y_pred = model.predict(X)
    y_pred[:,0] = unscale_y(y_pred[:,0])
    y_pred[:,1] = unscale_y(y_pred[:,1])
    y_pred[:,2] = unscale_y(y_pred[:,2])
    
    return y_pred
    
#Create buy coin function
def buy_coin(price, number_coin):
    global MY_POCKET
    global COIN_I_HAVE
    if number_coin == 0:
        return 
    
    MY_POCKET = MY_POCKET - price*number_coin
    COIN_I_HAVE += number_coin
    
#Create a function to calculate total coin i can buy with percent loss of my pocket
def how_many_coin_buy(today_price, accpet_loss = 0.2):
    if MY_POCKET*accpet_loss < today_price:
        if MY_POCKET*0.5 >= today_price:
             return MY_POCKET*0.5//today_price
        elif MY_POCKET >= today_price:
            return 1
        else: 
            return 0
    else:
        return MY_POCKET*accpet_loss//today_price
    
    
    
#Create sell coin function
def sell_coin(closing_price, number_coin):
    global MY_POCKET
    global COIN_I_HAVE
    MY_POCKET += closing_price*number_coin
    COIN_I_HAVE -= number_coin

# %%
SIMULATION_MARKET = dataset[2000-1:]
SIMULATION_MARKET.shape
# Out:
# (161, 8)

# %%
MY_POCKET = 2000
COIN_I_HAVE = 0
i = 1

total_win, total_lose = 0,0
last_open_price_bought = 0

#Create a report
row = 0
report = pd.DataFrame(columns = ['MoneyInPocket', 'CoinsInPocket', 'CoinsBuy', 'CoinsSell', 'PctChangeToday', 'Profit'], 
                      dtype = 'float64' )

for today in SIMULATION_MARKET.iterrows():
    if (i >= X_test.shape[0]):
        break 
    
    print(f"Day {i}:")
    tomorrow_closing_price = predict_closing_price(regressor, X_test[i])[:,1]
    today_closing_price = predict_closing_price(regressor, X_test[i-1])[:,1]
    diff_today_tomorrow = tomorrow_closing_price - today_closing_price
    
    pct_today_tomorrow = diff_today_tomorrow/today_closing_price
    
    number_coins_buy, number_coins_sell = 0, 0
    #If next day the price growing up, buy
    if pct_today_tomorrow >= 0.0025:
        number_coins_buy = how_many_coin_buy(accpet_loss=0.5, today_price=today[1][6])
        buy_coin(number_coin=number_coins_buy, price=today[1][target_index])
    
    #If next day the price down, sell
    if pct_today_tomorrow <= 0.0015:
        number_coins_sell = math.ceil(0.7*COIN_I_HAVE)
        sell_coin(number_coin=number_coins_sell, closing_price=today[1][target_index])
    
    #Make a report for today 
    report.loc[row, 'MoneyInPocket'] = MY_POCKET + COIN_I_HAVE * today[1][target_index]
    report.loc[row, 'CoinsInPocket'] = COIN_I_HAVE
    report.loc[row, 'CoinsBuy'] = number_coins_buy
    report.loc[row, 'CoinsSell'] = number_coins_sell
    report.loc[row, 'PctChangeToday'] = pct_today_tomorrow

    
    if i > 2:
        profit = MY_POCKET + COIN_I_HAVE * today[1][target_index] - report.loc[row-1, 'MoneyInPocket']
    else:
        profit = 0
        
    if profit > 0:
        print(f"Win today total profit: {profit}")
    elif profit < 0:
        print(f"Lose today total loss: {profit}")
    
    print(f"Today decide to buy {number_coins_buy} and sell {number_coins_sell} coins. Coins remain in pocket {COIN_I_HAVE}")
        
    report.loc[row, 'Profit'] = profit
    
    print("")
    row+=1
    i+=1
# Out:
# Day 1:
# Today decide to buy 7.0 and sell 0 coins. Coins remain in pocket 7.0
#
# Day 2:
# Today decide to buy 4.0 and sell 0 coins. Coins remain in pocket 11.0
#
# Day 3:
# Win today total profit: 16.782036810000136
# Today decide to buy 0 and sell 8 coins. Coins remain in pocket 3.0
#
# Day 4:
# Lose today total loss: -4.837658099999771
# Today decide to buy 0 and sell 3 coins. Coins remain in pocket 0.0
#
# Day 5:
# Today decide to buy 7.0 and sell 0 coins. Coins remain in pocket 7.0
#
# Day 6:
# Win today total profit: 16.667817040000045
# Today decide to buy 4.0 and sell 0 coins. Coins remain in pocket 11.0
#
# Day 7:
# Win today total profit: 116.10547256000018
# Today decide to buy 2.0 and sell 0 coins. Coins remain in pocket 13.0
#
# Day 8:
# Win today total profit: 170.36575309000045
# Today decide to buy 1.0 and sell 0 coins. Coins remain in pocket 14.0
#
# Day 9:
# Lose today total loss: -146.49384246000045
# Today decide to buy 1 and sell 0 coins. Coins remain in pocket 15.0
#
# Day 10:
# Win today total profit: 145.5604297499999
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 15.0
#
# Day 11:
# Win today total profit: 12.93790080000008
# Today decide to buy 0 and sell 11 coins. Coins remain in pocket 4.0
#
# Day 12:
# Lose today total loss: -18.298652680000032
# Today decide to buy 5.0 and sell 0 coins. Coins remain in pocket 9.0
#
# Day 13:
# Win today total profit: 144.71080497000003
# Today decide to buy 3.0 and sell 0 coins. Coins remain in pocket 12.0
#
# Day 14:
# Win today total profit: 178.74492899999996
# Today decide to buy 1.0 and sell 0 coins. Coins remain in pocket 13.0
#
# Day 15:
# Win today total profit: 0.7790016000003561
# Today decide to buy 1 and sell 0 coins. Coins remain in pocket 14.0
#
# Day 16:
# Win today total profit: 32.50251311999955
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 14.0
#
# Day 17:
# Win today total profit: 178.2999477000003
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 14.0
#
# Day 18:
# Win today total profit: 405.94247442000005
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 14.0
#
# Day 19:
# Lose today total loss: -165.1625942400001
# Today decide to buy 0 and sell 10 coins. Coins remain in pocket 4.0
#
# Day 20:
# Lose today total loss: -26.997014200000194
# Today decide to buy 5.0 and sell 0 coins. Coins remain in pocket 9.0
#
# Day 21:
# Win today total profit: 25.790018849999797
# Today decide to buy 3.0 and sell 0 coins. Coins remain in pocket 12.0
#
# Day 22:
# Win today total profit: 317.12335164000024
# Today decide to buy 0 and sell 9 coins. Coins remain in pocket 3.0
#
# Day 23:
# Lose today total loss: -30.311924039999667
# Today decide to buy 5.0 and sell 0 coins. Coins remain in pocket 8.0
#
# Day 24:
# Win today total profit: 78.45170623999957
# Today decide to buy 0 and sell 6 coins. Coins remain in pocket 2.0
#
# Day 25:
# Lose today total loss: -18.11223891999998
# Today decide to buy 0 and sell 2 coins. Coins remain in pocket 0.0
#
# Day 26:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 27:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 28:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 29:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 30:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 31:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 32:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 33:
# Today decide to buy 10.0 and sell 0 coins. Coins remain in pocket 10.0
#
# Day 34:
# Win today total profit: 103.10732270000017
# Today decide to buy 5.0 and sell 0 coins. Coins remain in pocket 15.0
#
# Day 35:
# Win today total profit: 39.51796139999988
# Today decide to buy 2.0 and sell 0 coins. Coins remain in pocket 17.0
#
# Day 36:
# Win today total profit: 181.10486053000022
# Today decide to buy 1.0 and sell 0 coins. Coins remain in pocket 18.0
#
# Day 37:
# Lose today total loss: -134.04627144000006
# Today decide to buy 0 and sell 13 coins. Coins remain in pocket 5.0
#
# Day 38:
# Lose today total loss: -1.5651733999998214
# Today decide to buy 0 and sell 4 coins. Coins remain in pocket 1.0
#
# Day 39:
# Win today total profit: 2.2162877200003095
# Today decide to buy 9.0 and sell 0 coins. Coins remain in pocket 10.0
#
# Day 40:
# Win today total profit: 77.77210179999975
# Today decide to buy 5.0 and sell 0 coins. Coins remain in pocket 15.0
#
# Day 41:
# Win today total profit: 17.52858735000018
# Today decide to buy 2.0 and sell 0 coins. Coins remain in pocket 17.0
#
# Day 42:
# Win today total profit: 199.07308362999993
# Today decide to buy 1.0 and sell 0 coins. Coins remain in pocket 18.0
#
# Day 43:
# Lose today total loss: -56.178148859999965
# Today decide to buy 1 and sell 0 coins. Coins remain in pocket 19.0
#
# Day 44:
# Win today total profit: 13.93612265999991
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 19.0
#
# Day 45:
# Win today total profit: 372.0022080200001
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 19.0
#
# Day 46:
# Win today total profit: 109.2290515499999
# Today decide to buy 0 and sell 14 coins. Coins remain in pocket 5.0
#
# Day 47:
# Lose today total loss: -56.410968850000245
# Today decide to buy 0 and sell 4 coins. Coins remain in pocket 1.0
#
# Day 48:
# Lose today total loss: -14.031484469999668
# Today decide to buy 0 and sell 1 coins. Coins remain in pocket 0.0
#
# Day 49:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 50:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 51:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 52:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 53:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 54:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 55:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 56:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 57:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 58:
# Today decide to buy 12.0 and sell 0 coins. Coins remain in pocket 12.0
#
# Day 59:
# Win today total profit: 134.60984292000012
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 12.0
#
# Day 60:
# Win today total profit: 6.621180359999926
# Today decide to buy 6.0 and sell 0 coins. Coins remain in pocket 18.0
#
# Day 61:
# Win today total profit: 3.564962639999976
# Today decide to buy 3.0 and sell 0 coins. Coins remain in pocket 21.0
#
# Day 62:
# Win today total profit: 198.3719978099998
# Today decide to buy 1.0 and sell 0 coins. Coins remain in pocket 22.0
#
# Day 63:
# Win today total profit: 48.56091284000013
# Today decide to buy 1.0 and sell 0 coins. Coins remain in pocket 23.0
#
# Day 64:
# Win today total profit: 18.791031740000108
# Today decide to buy 1 and sell 0 coins. Coins remain in pocket 24.0
#
# Day 65:
# Win today total profit: 158.7223130399998
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 24.0
#
# Day 66:
# Win today total profit: 218.78071272000034
# Today decide to buy 0 and sell 17 coins. Coins remain in pocket 7.0
#
# Day 67:
# Lose today total loss: -112.56127777999973
# Today decide to buy 8.0 and sell 0 coins. Coins remain in pocket 15.0
#
# Day 68:
# Win today total profit: 103.42053674999988
# Today decide to buy 5.0 and sell 0 coins. Coins remain in pocket 20.0
#
# Day 69:
# Win today total profit: 340.52273180000066
# Today decide to buy 2.0 and sell 0 coins. Coins remain in pocket 22.0
#
# Day 70:
# Win today total profit: 365.1090046999998
# Today decide to buy 0 and sell 16 coins. Coins remain in pocket 6.0
#
# Day 71:
# Lose today total loss: -109.44736535999982
# Today decide to buy 9.0 and sell 0 coins. Coins remain in pocket 15.0
#
# Day 72:
# Win today total profit: 113.69009355000071
# Today decide to buy 0 and sell 11 coins. Coins remain in pocket 4.0
#
# Day 73:
# Lose today total loss: -20.56261972000084
# Today decide to buy 10.0 and sell 0 coins. Coins remain in pocket 14.0
#
# Day 74:
# Win today total profit: 472.6096830000006
# Today decide to buy 6.0 and sell 0 coins. Coins remain in pocket 20.0
#
# Day 75:
# Lose today total loss: -39.714614399999846
# Today decide to buy 0 and sell 14 coins. Coins remain in pocket 6.0
#
# Day 76:
# Lose today total loss: -54.84056345999943
# Today decide to buy 9.0 and sell 0 coins. Coins remain in pocket 15.0
#
# Day 77:
# Win today total profit: 337.30647299999873
# Today decide to buy 5.0 and sell 0 coins. Coins remain in pocket 20.0
#
# Day 78:
# Win today total profit: 255.3386896000011
# Today decide to buy 2.0 and sell 0 coins. Coins remain in pocket 22.0
#
# Day 79:
# Win today total profit: 150.52810145999956
# Today decide to buy 1.0 and sell 0 coins. Coins remain in pocket 23.0
#
# Day 80:
# Win today total profit: 552.5094012400004
# Today decide to buy 1 and sell 0 coins. Coins remain in pocket 24.0
#
# Day 81:
# Lose today total loss: -140.4677884799994
# Today decide to buy 0 and sell 17 coins. Coins remain in pocket 7.0
#
# Day 82:
# Lose today total loss: -221.6276189399996
# Today decide to buy 0 and sell 5 coins. Coins remain in pocket 2.0
#
# Day 83:
# Lose today total loss: -22.359220639999876
# Today decide to buy 0 and sell 2 coins. Coins remain in pocket 0.0
#
# Day 84:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 85:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 86:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 87:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 88:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 89:
# Today decide to buy 15.0 and sell 0 coins. Coins remain in pocket 15.0
#
# Day 90:
# Win today total profit: 356.59594800000013
# Today decide to buy 8.0 and sell 0 coins. Coins remain in pocket 23.0
#
# Day 91:
# Win today total profit: 281.6665891199991
# Today decide to buy 3.0 and sell 0 coins. Coins remain in pocket 26.0
#
# Day 92:
# Lose today total loss: -29.825249479998092
# Today decide to buy 1.0 and sell 0 coins. Coins remain in pocket 27.0
#
# Day 93:
# Lose today total loss: -78.83730189000107
# Today decide to buy 1.0 and sell 0 coins. Coins remain in pocket 28.0
#
# Day 94:
# Win today total profit: 436.29060691999985
# Today decide to buy 1 and sell 0 coins. Coins remain in pocket 29.0
#
# Day 95:
# Win today total profit: 164.32681742000022
# Today decide to buy 0 and sell 21 coins. Coins remain in pocket 8.0
#
# Day 96:
# Lose today total loss: -61.83320303999972
# Today decide to buy 10.0 and sell 0 coins. Coins remain in pocket 18.0
#
# Day 97:
# Win today total profit: 460.7936310599998
# Today decide to buy 6.0 and sell 0 coins. Coins remain in pocket 24.0
#
# Day 98:
# Win today total profit: 276.7317100799992
# Today decide to buy 2.0 and sell 0 coins. Coins remain in pocket 26.0
#
# Day 99:
# Win today total profit: 1294.8669510399995
# Today decide to buy 1.0 and sell 0 coins. Coins remain in pocket 27.0
#
# Day 100:
# Lose today total loss: -68.2216519499998
# Today decide to buy 1 and sell 0 coins. Coins remain in pocket 28.0
#
# Day 101:
# Lose today total loss: -203.18988564000028
# Today decide to buy 0 and sell 20 coins. Coins remain in pocket 8.0
#
# Day 102:
# Win today total profit: 0.92128872000103
# Today decide to buy 10.0 and sell 0 coins. Coins remain in pocket 18.0
#
# Day 103:
# Win today total profit: 721.4768746200007
# Today decide to buy 0 and sell 13 coins. Coins remain in pocket 5.0
#
# Day 104:
# Lose today total loss: -135.60737979999976
# Today decide to buy 11.0 and sell 0 coins. Coins remain in pocket 16.0
#
# Day 105:
# Win today total profit: 288.9519425599992
# Today decide to buy 0 and sell 12 coins. Coins remain in pocket 4.0
#
# Day 106:
# Lose today total loss: -297.21577892000096
# Today decide to buy 0 and sell 3 coins. Coins remain in pocket 1.0
#
# Day 107:
# Win today total profit: 13.824488840000413
# Today decide to buy 0 and sell 1 coins. Coins remain in pocket 0.0
#
# Day 108:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 109:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 110:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 111:
# Today decide to buy 17.0 and sell 0 coins. Coins remain in pocket 17.0
#
# Day 112:
# Win today total profit: 218.45014058999914
# Today decide to buy 0 and sell 12 coins. Coins remain in pocket 5.0
#
# Day 113:
# Lose today total loss: -525.4956805499987
# Today decide to buy 0 and sell 4 coins. Coins remain in pocket 1.0
#
# Day 114:
# Win today total profit: 22.755958419998933
# Today decide to buy 0 and sell 1 coins. Coins remain in pocket 0.0
#
# Day 115:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 116:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 117:
# Today decide to buy 30.0 and sell 0 coins. Coins remain in pocket 30.0
#
# Day 118:
# Win today total profit: 1214.2430048999995
# Today decide to buy 20.0 and sell 0 coins. Coins remain in pocket 50.0
#
# Day 119:
# Lose today total loss: -24.811306000001423
# Today decide to buy 6.0 and sell 0 coins. Coins remain in pocket 56.0
#
# Day 120:
# Win today total profit: 880.6803510400023
# Today decide to buy 3.0 and sell 0 coins. Coins remain in pocket 59.0
#
# Day 121:
# Lose today total loss: -360.0908844700007
# Today decide to buy 0 and sell 42 coins. Coins remain in pocket 17.0
#
# Day 122:
# Lose today total loss: -268.6074040100011
# Today decide to buy 0 and sell 12 coins. Coins remain in pocket 5.0
#
# Day 123:
# Lose today total loss: -67.56278274999931
# Today decide to buy 0 and sell 4 coins. Coins remain in pocket 1.0
#
# Day 124:
# Win today total profit: 7.170120269998733
# Today decide to buy 34.0 and sell 0 coins. Coins remain in pocket 35.0
#
# Day 125:
# Win today total profit: 596.9406688000017
# Today decide to buy 0 and sell 25 coins. Coins remain in pocket 10.0
#
# Day 126:
# Lose today total loss: -50.52981270000055
# Today decide to buy 27.0 and sell 0 coins. Coins remain in pocket 37.0
#
# Day 127:
# Win today total profit: 158.48176330000024
# Today decide to buy 14.0 and sell 0 coins. Coins remain in pocket 51.0
#
# Day 128:
# Win today total profit: 296.9323178099985
# Today decide to buy 0 and sell 36 coins. Coins remain in pocket 15.0
#
# Day 129:
# Lose today total loss: -213.2125445999991
# Today decide to buy 0 and sell 11 coins. Coins remain in pocket 4.0
#
# Day 130:
# Lose today total loss: -23.373189160000038
# Today decide to buy 0 and sell 3 coins. Coins remain in pocket 1.0
#
# Day 131:
# Win today total profit: 3.6107129699994402
# Today decide to buy 0 and sell 1 coins. Coins remain in pocket 0.0
#
# Day 132:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 133:
# Today decide to buy 38.0 and sell 0 coins. Coins remain in pocket 38.0
#
# Day 134:
# Win today total profit: 417.14810992000093
# Today decide to buy 0 and sell 27 coins. Coins remain in pocket 11.0
#
# Day 135:
# Lose today total loss: -43.29152684999826
# Today decide to buy 0 and sell 8 coins. Coins remain in pocket 3.0
#
# Day 136:
# Lose today total loss: -15.967583010000453
# Today decide to buy 0 and sell 3 coins. Coins remain in pocket 0.0
#
# Day 137:
# Today decide to buy 39.0 and sell 0 coins. Coins remain in pocket 39.0
#
# Day 138:
# Win today total profit: 347.7248189999991
# Today decide to buy 19.0 and sell 0 coins. Coins remain in pocket 58.0
#
# Day 139:
# Win today total profit: 117.05665154000053
# Today decide to buy 9.0 and sell 0 coins. Coins remain in pocket 67.0
#
# Day 140:
# Win today total profit: 382.5915820400005
# Today decide to buy 0 and sell 47 coins. Coins remain in pocket 20.0
#
# Day 141:
# Lose today total loss: -244.00974919999862
# Today decide to buy 0 and sell 14 coins. Coins remain in pocket 6.0
#
# Day 142:
# Win today total profit: 3.5805411000001186
# Today decide to buy 0 and sell 5 coins. Coins remain in pocket 1.0
#
# Day 143:
# Lose today total loss: -10.7000628400001
# Today decide to buy 0 and sell 1 coins. Coins remain in pocket 0.0
#
# Day 144:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 145:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 146:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 147:
# Today decide to buy 0 and sell 0 coins. Coins remain in pocket 0.0
#
# Day 148:
# Today decide to buy 55.0 and sell 0 coins. Coins remain in pocket 55.0
#
# Day 149:
# Win today total profit: 319.52884260000064
# Today decide to buy 0 and sell 39 coins. Coins remain in pocket 16.0
#
# Day 150:
# Lose today total loss: -140.7497305600009
# Today decide to buy 0 and sell 12 coins. Coins remain in pocket 4.0
#
# Day 151:
# Win today total profit: 3.878063120000661
# Today decide to buy 51.0 and sell 0 coins. Coins remain in pocket 55.0
#
# Day 152:
# Win today total profit: 312.9848447000004
# Today decide to buy 25.0 and sell 0 coins. Coins remain in pocket 80.0

# %%
report.describe()
# Out:
#        MoneyInPocket  CoinsInPocket    CoinsBuy   CoinsSell  PctChangeToday  \
# count     152.000000     152.000000  152.000000  152.000000      152.000000
# mean     7244.768142      13.111842    4.105263    3.578947        0.000807
# std      3850.815052      15.229176    9.121082    8.236992        0.036914
# min      2000.000000       0.000000    0.000000    0.000000       -0.135574
# 25%      3752.976499       0.000000    0.000000    0.000000       -0.019221
# 50%      6419.747364      10.000000    0.000000    0.000000        0.001630
# 75%     10569.272655      19.000000    4.250000    2.250000        0.024385
# max     13852.117209      80.000000   55.000000   47.000000        0.090894
#
#             Profit
# count   152.000000
# mean     77.489178
# std     233.823690
# min    -525.495681
# 25%      -6.303259
# 50%       0.000000
# 75%     146.802348
# max    1294.866951

# %%
f, ax = plt.subplots(4, 1, sharex=True, figsize=(20,15))

#Plot my pocket
ax[0].plot(report['MoneyInPocket'], color = 'blue')
ax[0].set_title('My pocket over time')
ax[0].set_xlabel('Time')
ax[0].set_ylabel('Money($)')

#Plot loss each day
ax[1].plot(report['Profit'], color = 'red')
ax[1].set_title("Profit over time")
ax[1].set_xlabel('Time')
ax[1].set_ylabel('Money($)')

#Plot coins track sell and buy in each day
ax[2].plot(report['CoinsBuy'], color = 'red', label='Number of coin buy')
ax[2].plot(report['CoinsSell'], color = 'blue', label='Number of coin sell')
ax[2].plot(report['CoinsInPocket'], color = 'orange', label='Coins remian in pocket')
ax[2].set_title("Coins buy plus sell in each day")
ax[2].set_xlabel('Time')
ax[2].set_ylabel('Total coins')
ax[2].legend()

#Plot predicted value
ax[3].plot(y_pred_current_day, color = 'green', label = "Predict price")
ax[3].plot(y_real_current_day, color = 'red', label = "Real price in makert")
ax[3].set_title("Predict Litecoin closing over time")
ax[3].set_xlabel('Time')
ax[3].set_ylabel('Closing Price')
ax[3].legend()


plt.legend()
plt.show()

# %%
SIMULATION_MARKET.tail()
# Out:
#             Bitcoin_High  Bitcoin_Low  Bitcoin_Open  Bitcoin_Close  \
# Date
# 2021-07-02   33939.58870  32770.68078   33549.60018    33897.04859
# 2021-07-03   34909.25990  33402.69654   33854.42136    34668.54840
# 2021-07-04   35937.56715  34396.47746   34665.56487    35287.77977
# 2021-07-05   35284.34443  33213.66103   35284.34443    33746.00246
# 2021-07-06   35038.53636  33599.91617   33723.50966    34235.19345
#
#             Litecoin_High  Litecoin_Low  Litecoin_Open  Litecoin_Close
# Date
# 2021-07-02     138.787700    130.935471     137.299274      136.943696
# 2021-07-03     141.356011    134.945288     136.930584      140.279688
# 2021-07-04     147.836059    137.096427     140.317998      144.905849
# 2021-07-05     144.849333    134.960263     144.849333      138.073246
# 2021-07-06     142.703568    135.924837     137.951668      138.985636

# %%
print(f"After 160 days, total coins remain in pocket {COIN_I_HAVE}, total profit is {MY_POCKET + COIN_I_HAVE*143.7029 - 2000}")
# Out:
# After 160 days, total coins remain in pocket 80.0, total profit is 12760.517873780005

# %% [markdown]
# Not bad with a simple custom strategy, which total profit is 12760$. With that money, i can buy some ice cream to eat this month.

# %% [markdown]
# I'm just playing with this, maybe it do not work quite well in real market. You should have to test it more for more trust able result. Please fell free to comment bellow if you find anything, or find any bug in my code. Thanks for reading!!

# %%
#Save model
regressor.save('LiteCoinModel.h5')
